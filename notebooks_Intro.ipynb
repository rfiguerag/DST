# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **RICARDO**

# %% [markdown]
# *Im interested in data science because i see every task as a challange that allows me to be creative in the form to solve it*

# %% [markdown]
# *My code multiplies the first variable with the second variable*

# %%
A = 5
B = 20
C = A*B
print(C)
# Out:
# 100

# %% [markdown]
# Hello world with horizontal
#
# ---
#
# 1. First
# 2. Second
# 3. Third
#
# >Epa tu
